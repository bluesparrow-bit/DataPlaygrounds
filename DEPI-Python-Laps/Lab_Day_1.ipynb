# %% [markdown]
# # **Lab DAY1**

# %% [markdown]
# ---

# %% [markdown]
# ## Print a message onto the screen

# %% [markdown]
# ### Single and duble quotes do the same job

# %%
print('Hello world!')

# %%
print("Hello world!")

# %% [markdown]
# ### multiple lines

# %%
print('''
Hello world!
My name is ali
I am a python developer''')

# %% [markdown]
# ## Comments

# %% [markdown]
# As your programs become longer and more complicated, you should add notes within your programs that describe your overall approach to the problem you’re solving. A comment allows you to write notes in English within your programs.

# %% [markdown]
# ### Single comment

# %%
# Say hello to everyone.
print("Hello Python people!")

# %% [markdown]
# ### multi comment

# %%
'''
My name is mahmoud ali
Age : 14
Address : Egypt
'''
print('test')

# %% [markdown]
# ## Variables

# %% [markdown]
# * Variables are containers for storing data values .
# * variable is created the moment you first assign a value to it.
# * Variables do not need to be declared with any particular type and can even change type after they have been set.

# %% [markdown]
# ### Variable

# %%
x = 5

# %%
y = "ahmed"

# %%
print(x)

# %%
print(y)

# %%
x = 4

# %%
x = "Sally"

# %%
print(x)

# %% [markdown]
# ### Rules for Python variables

# %% [markdown]
# * A variable name must start with a letter or the underscore character
# * A variable name cannot start with a number
# * A variable name can only contain alpha-numeric characters and underscores (A-z, 0-9, and _ )
# * Variable names are case-sensitive (age, Age and AGE are three different variables)

# %% [markdown]
# #### Legal variable names

# %%
myvar = "Ahmed"

# %%
my_var = "Ahmed"

# %%
_my_var = "Ahmed"

# %%
myVar = "Ahmed"

# %%
MYVAR = "Ahmed"

# %%
myvar2 = "Ahmed"

# %% [markdown]
# #### Illegal variable names

# %%
2myvar = "Ahmed"

# %%
my-var = "Ahmed"

# %%
my var = "Ahmed"

# %% [markdown]
# ### Constants

# %% [markdown]
# A constant is like a variable whose value stays the same throughout the life
# of a program. Python doesn’t have built-in constant types, but Python
# programmers use all capital letters to indicate a variable should be treated
# as a constant and never be changed

# %%
MAX_CONNECTIONS = 5000

# %% [markdown]
# ## Data Types

# %% [markdown]
# ### String

# %% [markdown]
# A string is a series of characters. Anything inside quotes is considered astring in Python

# %%
name = "Ali"

# %%
print(name)

# %% [markdown]
# Upper

# %%
print(name.upper())

# %% [markdown]
# Lower

# %%
print(name.lower())

# %% [markdown]
# String concatenation

# %%
first_name = "Mahmoud"
last_name = "Ali"

# %%
print(first_name, last_name )

# %%
print(first_name + last_name )

# %%
print(f"{first_name} {last_name}")

# %% [markdown]
# tab

# %%
print("\tPython")

# %% [markdown]
# new line

# %%
print("Languages:\nPython\nC\nJavaScript")

# %% [markdown]
# ### Numbers

# %% [markdown]
# Integer or Float (1 , 1.0)

# %% [markdown]
# sum

# %%
print(2 + 3)

# %% [markdown]
# sub

# %%
print(2 - 3)

# %% [markdown]
# multi

# %%
print(2 * 3)

# %% [markdown]
# divide

# %%
print(2 / 3)

# %% [markdown]
# power

# %%
print(2 ** 3)
print(pow(2,3))

# %% [markdown]
# brackets order

# %%
print((1+2)*4)

# %% [markdown]
# When you divide any two numbers, even if they are integers that result in a whole number, you’ll always get a float:

# %%
x=4/2

# %%
print(x)

# %%
type(x)

# %% [markdown]
# #### Try It Yourself
# Write addition, subtraction, multiplication, and division operations that each result in the number
# 8. Be sure to enclose your operations in print() calls to see the results.

# %% [markdown]
# ## List

# %% [markdown]
# - You can make a list that includes strings, digits.
# - You can put anything you want into a list.
# - list usually contains more than one element.
# - a good idea to make the name of your list plural, such as letters, digits, or names.

# %% [markdown]
# ### Creation

# %%
names = ['mahmoud', 'ali', 'ahmed', 'mohamed']

# %%
my_list = ['mahmoud',20, 'ahmed', '300']

# %%
Empty_list = []

# %% [markdown]
# ### Accessing Elements in a List NOTE:

# %% [markdown]
# - Index Positions Start at 0, Not 1
# - the last element in your list will have the index of -1

# %%
print(names[0])

# %%
print(names[-1])

# %% [markdown]
# ### Modifying

# %%
print(names)

# %%
names[0] = 'Max'

# %%
print(names)

# %% [markdown]
# ### Adding

# %%
names.append('Basma')

# %%
print(names)

# %% [markdown]
# Empty List

# %%
Empty_list.append('ibrahim')

# %%
Empty_list.append('mohamed')

# %%
Empty_list.append('ahmed')

# %%
Empty_list.append('ali')

# %%
Empty_list.append(20)

# %%
print(Empty_list)

# %% [markdown]
# You can add a new element at any position in your list by using the insert() method.

# %%
Empty_list.insert(1, 18)

# %%
print(Empty_list)

# %% [markdown]
# extend

# %%
L1 = [1,2,3,4]

# %%
L2 = [5,6,7,8]

# %%
L1.extend(L2)

# %%
print(L1)

# %% [markdown]
# ### Removing

# %% [markdown]
# If you know the position of the item you want to remove from a list, you can use the del statement.

# %%
print(Empty_list)

# %%
del Empty_list[1]

# %%
print(Empty_list)

# %% [markdown]
# Removing an Item Using the pop()
#
# The pop() method removes the last item in a list, but it lets you work with that item after
# removing it. The term pop comes from thinking of a list as a stack of items and popping one item
# off the top of the stack. In this analogy, the top of a stack corresponds to the end of a list.
# Let’s pop a motorcycle from the list of motorcycles

# %% [markdown]
# Last index

# %%
popped1 = Empty_list.pop()

# %%
print(popped1)

# %%
print(Empty_list)

# %% [markdown]
# By index

# %%
popped2 = Empty_list.pop(2)

# %%
print(popped2)

# %%
print(Empty_list)

# %% [markdown]
# Removing all List

# %%
del Empty_list[:]

# %%
print(Empty_list)

# %% [markdown]
# Removing an Item by Value

# %%
Empty_list.append('Ibrahim')
Empty_list.append('ali')
Empty_list.append('Ibrahim')

# %%
print(Empty_list)

# %%
Empty_list.remove('Ibrahim')

# %%
print(Empty_list)

# %% [markdown]
# The remove() method deletes only the first occurrence of the value you specify.

# %% [markdown]
# ### Organizing a List

# %%
numbers = [5, 3, 1, 4,2]

# %%
numbers.sort()
print(numbers)

# %%
numbers.reverse()
print(numbers)

# %% [markdown]
# Notice that reverse() doesn’t sort backward.

# %%
numbers.reverse()
print(numbers)

# %% [markdown]
# Sorting a list of strings

# %%
names = ['mahmoud', 'ali', 'ahmed', 'mohamed']

# %%
names.sort()
print(names)

# %% [markdown]
# Length of a List

# %%
print(len(names))

# %% [markdown]
# Avoiding Index Errors When Working with Lists

# %%
names = ['mahmoud', 'ali', 'ahmed', 'mohamed']
print(names[4])

# %% [markdown]
# Looping

# %%
for x in range(4):
    print(names[x])
print('Loop Finished')

# %%
for y in range(len(names)):
    print(names[y])
print('Loop Finished')

# %%
for name in names:
    print(name)
print('Loop Finished')

# %% [markdown]
# funcation() range

# %%
numbers = list(range(1, 6))
print(numbers)

# %%
even_numbers = list(range(2, 11, 2))
print(even_numbers)

# %%
even_numbers = list(range(4))
print(even_numbers)

# %%
squares = []

# %%
squares = [value**2 for value in range(1, 11)]
print(squares)

# %% [markdown]
# Simple Statistics with a List of Numbers

# %%
digits = [1, 2, 3, 4, 5, 6, 7, 8, 9, 0]

# %%
print(min(digits))

# %%
print(max(digits))

# %%
print(sum(digits))

# %% [markdown]
# ### Quiz
# create a list of squares from 1 to 10 numbers

# %%
#solution

for value in range(1, 11):
    square = value ** 2
    squares.append(square)
print(squares)

# %% [markdown]
# ## Assignment

# %% [markdown]
# **Use Python lists to create and modify a guest list for a dinner party.**
#
# - Create a list of at least five guests and print personalized invitations.
# - Replace one guest who can’t attend with a new invitee.
# - Expand the list by adding three more guests at different positions using `insert()` and `append()`.
# - Simulate a venue change by limiting the guest list to only two people:
#   - Use `pop()` to remove guests one by one, printing a message for each.
#   - Ensure the final two guests receive a confirmation message.
# - Completely clear the list using `del` and verify it’s empty.
# - Add an extra challenge: Sort the guest list alphabetically before sending invitations.
